# %%
import pandas as pd

df = pd.read_csv("student_scores.csv")

print(df.head())

print("\nMissing Values:")
print(df.isnull().sum())

# Fill missing values
df.fillna(df.mean(numeric_only=True), inplace=True)

print("\nDuplicate Rows:")
print(df.duplicated().sum())

# Remove duplicates
df.drop_duplicates(inplace=True)

print("\nStatistics:")
print(df.describe())

# Save cleaned dataset
df.to_csv("cleaned_student_scores.csv", index=False)

print("\nDataset cleaned successfully!")
# Out:
#    Student_ID   Name  Maths  Science  English
# 0         101   Asha   85.0     92.0     88.0
# 1         102  Rahul   90.0      NaN     91.0
# 2         103  Priya    NaN     81.0     79.0
# 3         104  Kiran   78.0     75.0      NaN
# 4         104  Kiran   78.0     75.0      NaN
#
# Missing Values:
# Student_ID    0
# Name          0
# Maths         1
# Science       1
# English       2
# dtype: int64
#
# Duplicate Rows:
# 1
#
# Statistics:
#        Student_ID      Maths    Science    English
# count    5.000000   5.000000   5.000000   5.000000
# mean   103.000000  84.960000  83.880000  87.000000
# std      1.581139   4.594344   6.735874   4.743416
# min    101.000000  78.000000  75.000000  79.000000
# 25%    102.000000  83.800000  81.000000  87.000000
# 50%    103.000000  85.000000  82.400000  88.000000
# 75%    104.000000  88.000000  89.000000  90.000000
# max    105.000000  90.000000  92.000000  91.000000
#
# Dataset cleaned successfully!
